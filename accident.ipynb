# %%
import pandas as pd
from google.colab import drive
drive.mount('/content/drive')
file_path = '/content/drive/MyDrive/accident.csv'
# Out:
# Mounted at /content/drive

# %%
import io
df = pd.read_csv(io.StringIO(csv_data))

# 2. 조건에 맞는 데이터 필터링
# '다발지시군구' 컬럼에서 "서울특별시"가 포함된 행을 선택
# '가해자차종' 또는 '피해자차종' 컬럼에 "자전거"가 포함된 행을 선택
filtered_df = df[
    (df['다발지시군구'].str.contains('서울특별시')) &
    ((df['가해자차종'].str.contains('자전거')) | (df['피해자차종'].str.contains('자전거')))
]

# 3. 결과 확인
print("서울 내 자전거 관련 사고 데이터:")
print(filtered_df)

# 필터링된 데이터를 새로운 CSV 파일로 저장하고 싶다면 (선택 사항)
# filtered_df.to_csv('서울_자전거_사고_데이터.csv', index=False, encoding='utf-8-sig')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-2-3286022199.py in <cell line: 0>()
#       1 import io
# ----> 2 df = pd.read_csv(io.StringIO(csv_data))
#       3
#       4 # 2. 조건에 맞는 데이터 필터링
#       5 # '다발지시군구' 컬럼에서 "서울특별시"가 포함된 행을 선택
#
# NameError: name 'csv_data' is not defined
